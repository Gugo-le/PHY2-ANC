# %% [markdown]
# # 노이즈 캔슬링 연구

# %%
# 필요 라이브러리 import

import soundfile
import IPython
import matplotlib.pyplot as plt

# %%
# 사운드파일 불러오기

soundfile_path = './audio/iloveyou_kakao.mp3'
sound, sampling_rate = soundfile.read(soundfile_path)

## sound = 사운드파일의 강도를 담은 배열
## sampling_rate = 재생 속도

# %%
# 불러온 사운드파일 들어보기
IPython.display.Audio(sound, rate = sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 역위상 음원 만들기

sound_reverse = sound * (-1)

# %%
# 역위상 음원 들어보기
IPython.display.Audio(sound_reverse, rate = sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 원음과 역위상 음원 그래프로 비교

plt.figure(figsize = (20, 10))
plt.subplot(1, 2, 1)
plt.plot(range(len(sound)), sound)
plt.title('sound_original')
plt.subplot(1, 2, 2)
plt.plot(range(len(sound_reverse)), sound_reverse)
plt.title('sound_reverse')
plt.show()

# %%
# 5000 ~ 5200 부분만 그래프로 그려보기

start = 5000
end = 5200

plt.figure(figsize = (20, 10))
plt.subplot(1, 2, 1)
plt.plot(range(len(sound[start:end])), sound[start:end])
plt.title('sound_original')
plt.subplot(1, 2, 2)
plt.plot(range(len(sound_reverse[start:end])), sound_reverse[start:end])
plt.title('sound_reverse')
plt.show()

# %% [markdown]
# # 노이즈 캔슬링

# %%
# 사운드파일 불러오기, 역위상 음원 만들기 (위에서 했던 작업)

soundfile_path = './audio/iloveyou_kakao.mp3'
sound, sampling_rate = soundfile.read(soundfile_path)
sound_reverse = sound * (-1)

# %%
# 원 사운드와 역위상 음원 더하기
noise_canceling = sound + sound_reverse

# %%
# 들어보기 (원음)
IPython.display.Audio(sound, rate = sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 들어보기 (역위상 음원)
IPython.display.Audio(sound_reverse, rate = sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 들어보기 (노이즈캔슬링)
IPython.display.Audio(noise_canceling, rate = sampling_rate)
# Out:
# /Users/gugo-le/Library/Python/3.11/lib/python/site-packages/IPython/lib/display.py:187: RuntimeWarning: invalid value encountered in divide
#   scaled = data / normalization_factor * 32767
# /Users/gugo-le/Library/Python/3.11/lib/python/site-packages/IPython/lib/display.py:188: RuntimeWarning: invalid value encountered in cast
#   return scaled.astype("<h").tobytes(), nchan
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
